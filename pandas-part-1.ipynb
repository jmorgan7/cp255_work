# %% [markdown]
# # Getting started with data analysis using Pandas
#
# Notebook developed by Sam Maurer

# %% [markdown]
# Pandas is a popular Python libary for working with data: https://pandas.pydata.org
#
# To use it in this notebook, we'll import it and give it the standard alias "pd":

# %%
import pandas as pd

# %% [markdown]
# ## 1. Pandas data objects: Series and DataFrames
#
# Pandas has two standard structures for working with data:
# - "Series" are like lists
# - "DataFrames" are like tables
#
# Pandas data objects include some special metadata, like column names and indexes.

# %%
x_list = [1.4, 5.98, 12, 0.0]

print(x_list)
# Out:
# [1.4, 5.98, 12, 0.0]

# %%
type(x_list)  # type() is a function that identifies the data type of a variable
# Out:
# list

# %%
x_series = pd.Series({"x": [1.4, 5.98, 12, 0.0]})

print(x_series)
# Out:
# x    [1.4, 5.98, 12, 0.0]
# dtype: object

# %%
type(x_series)
# Out:
# pandas.core.series.Series

# %%
data = pd.DataFrame({"x": [1.4, 5.98, 12, 0.0], "y": [17, 40, 52, 0]})

print(data)
# Out:
#        x   y
# 0   1.40  17
# 1   5.98  40
# 2  12.00  52
# 3   0.00   0

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# As you might expect, each of the columns of a DataFrame is a Series:

# %%
type(data['x'])

# %% [markdown]
# Pandas is part of the same ecosystem as Matplotlib and NumPy. Pandas DataFrames even provide built-in shortcuts to quickly plot data with Matplotlib.
#
# This line allows the graphics to display directly in the notebook:

# %%
# %matplotlib inline

# %%
data.plot.scatter('x', 'y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f76b0f9bf396> in <module>
# ----> 1 data.plot.scatter('x', 'y')
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## 2. Loading and displaying data
#
# We're going to look at some U.S. housing cost data from Zillow: https://www.zillow.com/research/data/
#
# Pandas can load data directly from a URL. In this case, we'll get the median asking rents for 2-bedroom units:

# %%
url = "http://files.zillowstatic.com/research/public/Metro/Metro_MedianRentalPrice_2Bedroom.csv"

# %%
df = pd.read_csv(url)

# %% [markdown]
# If that cell ran successfully, the data has been loaded.
#
# Alternatively, you can load data "locally" -- from a file on the machine where Python is running. In this case, you'd pass to `pd.read_csv()` a **file path** instead of a URL.
#
# And now we have a DataFrame!

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# How much data is there? `len()` is a standard Python function to get the length of things. If we pass it a DataFrame, it tells us the number of rows:

# %%
len(df)
# Out:
# 384

# %% [markdown]
# And there's a DataFrame property called `shape` that tells us a little more:

# %%
df.shape  # rows x columns
# Out:
# (384, 122)

# %% [markdown]
# (In case you're curious why there aren't any parentheses at the end of `df.shape`, it's because "shape" isn't a function that we're executing, but rather a metadata property of the DataFrame.)
#
# We can display the data as a table, too, although Jupyter notebooks aren't great for browsing through raw data. Usually, displaying a few rows is enough to give us a sense of what we're working with:

# %%
df.head()
# Out:
#                            RegionName  SizeRank  2010-01  2010-02  2010-03  \
# 0                       United States         0      NaN      NaN   1350.0
# 1                        New York, NY         1      NaN      NaN      NaN
# 2  Los Angeles-Long Beach-Anaheim, CA         2      NaN   1950.0   1900.0
# 3                         Chicago, IL         3      NaN      NaN   1345.0
# 4               Dallas-Fort Worth, TX         4      NaN      NaN      NaN
#
#    2010-04  2010-05  2010-06  2010-07  2010-08   ...     2019-03  2019-04  \
# 0   1350.0   1350.0   1400.0   1300.0   1250.0   ...      1650.0   1668.0
# 1      NaN      NaN      NaN      NaN      NaN   ...      2450.0   2500.0
# 2   1992.5   1980.0   1997.0   2100.0   2150.0   ...      2595.0   2605.0
# 3   1350.0   1350.0   1400.0   1400.0   1375.0   ...      1795.0   1765.0
# 4      NaN      NaN      NaN      NaN      NaN   ...      1611.0   1600.0
#
#    2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 0   1675.0   1683.0   1683.0   1660.0   1632.0   1600.0   1599.0   1595.0
# 1   2500.0   2550.0   2500.0   2545.0   2500.0   2450.0   2400.0   2375.0
# 2   2620.0   2628.0   2635.0   2650.0   2670.0   2650.0   2650.0   2650.0
# 3   1750.0   1750.0   1750.0   1705.0   1700.0   1640.0   1615.0   1600.0
# 4   1595.0   1585.0   1582.0   1575.0   1580.0   1575.0   1572.0   1582.0
#
# [5 rows x 122 columns]

# %% [markdown]
# But some of the columns are missing! We can fix this by adjusting a Pandas library setting:

# %%
pd.set_option("display.max.columns", None)  # None means no maximum, a.k.a. everything

# %%
df.head()
# Out:
#                            RegionName  SizeRank  2010-01  2010-02  2010-03  \
# 0                       United States         0      NaN      NaN   1350.0
# 1                        New York, NY         1      NaN      NaN      NaN
# 2  Los Angeles-Long Beach-Anaheim, CA         2      NaN   1950.0   1900.0
# 3                         Chicago, IL         3      NaN      NaN   1345.0
# 4               Dallas-Fort Worth, TX         4      NaN      NaN      NaN
#
#    2010-04  2010-05  2010-06  2010-07  2010-08  2010-09  2010-10  2010-11  \
# 0   1350.0   1350.0   1400.0   1300.0   1250.0   1225.0   1250.0   1250.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1992.5   1980.0   1997.0   2100.0   2150.0   1947.5   1895.0   1895.0
# 3   1350.0   1350.0   1400.0   1400.0   1375.0   1357.0   1400.0   1400.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2010-12  2011-01  2011-02  2011-03  2011-04  2011-05  2011-06  2011-07  \
# 0   1295.0   1200.0   1250.0   1300.0   1400.0   1400.0   1395.0   1395.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1900.0   1800.0   1840.0   1825.0   1875.0   1900.0   1900.0   1900.0
# 3   1475.0   1432.5   1499.0   1500.0   1550.0   1595.0   1650.0   1600.0
# 4      NaN      NaN    995.0   1000.0    975.0    989.0    995.0    995.0
#
#    2011-08  2011-09  2011-10  2011-11  2011-12  2012-01  2012-02  2012-03  \
# 0   1400.0   1350.0   1250.0   1200.0   1250.0   1250.0   1250.0   1300.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1860.0   1800.0   1750.0   1700.0   1700.0   1719.5   1750.0   1785.0
# 3   1595.0   1600.0   1550.0   1495.0   1495.0   1495.0   1475.0   1450.0
# 4    950.0    948.0    900.0    899.0    950.0    953.0    965.0   1005.0
#
#    2012-04  2012-05  2012-06  2012-07  2012-08  2012-09  2012-10  2012-11  \
# 0   1325.0   1375.0   1345.0   1319.0   1325.0   1300.0   1295.0   1300.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1775.0   1789.0   1780.0   1770.0   1785.0   1800.0   1790.0   1780.0
# 3   1399.0   1425.0   1500.0   1485.0   1480.0   1495.0   1500.0   1450.0
# 4    970.0    995.0   1008.0   1000.0   1002.0   1020.0   1029.0   1030.0
#
#    2012-12  2013-01  2013-02  2013-03  2013-04  2013-05  2013-06  2013-07  \
# 0   1300.0   1250.0   1300.0   1350.0   1350.0   1370.0   1350.0   1405.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1735.0   1750.0   1797.0   1815.0   1815.0   1850.0   1850.0   1845.0
# 3   1495.0   1451.0   1550.0   1500.0   1500.0   1600.0   1633.0   1650.0
# 4   1095.0   1189.0   1096.0   1125.0   1110.0   1151.0   1181.0   1188.0
#
#    2013-08  2013-09  2013-10  2013-11  2013-12  2014-01  2014-02  2014-03  \
# 0   1425.0   1500.0   1600.0   1500.0   1600.0   1600.0   1595.0   1600.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   1800.0   1900.0   1900.0   1800.0   1995.0   1950.0   1905.0   1900.0
# 3   1655.0   1650.0   1595.0   1600.0   1695.0   1550.0   1500.0   1500.0
# 4   1065.0   1205.0   1341.5   1350.0   1350.0   1299.0   1250.0   1279.0
#
#    2014-04  2014-05  2014-06  2014-07  2014-08  2014-09  2014-10  2014-11  \
# 0   1638.0   1715.0   1750.0   1550.0   1550.0   1519.0   1500.0   1495.0
# 1      NaN      NaN      NaN      NaN   2545.0   2595.0   2595.0   2550.0
# 2   1945.0   1995.0   2022.0   2090.0   2095.0   2100.0   2149.0   2145.0
# 3   1545.0   1600.0   1600.0   1695.0   1600.0   1695.0   1650.0   1600.0
# 4   1328.0   1250.0   1250.0   1239.0   1225.0   1200.0   1195.0   1251.0
#
#    2014-12  2015-01  2015-02  2015-03  2015-04  2015-05  2015-06  2015-07  \
# 0   1450.0   1475.0   1500.0   1528.0   1540.0   1599.0   1580.0   1595.0
# 1   2500.0   2500.0   2500.0   2500.0   2500.0   2595.0   2545.0   2500.0
# 2   2161.5   2165.0   2160.0   2155.0   2195.0   2200.0   2210.0   2215.0
# 3   1495.0   1500.0   1625.0   1550.0   1600.0   1600.0   1600.0   1600.0
# 4   1268.0   1256.0   1250.0   1243.0   1260.0   1269.5   1276.0   1294.0
#
#    2015-08  2015-09  2015-10  2015-11  2015-12  2016-01  2016-02  2016-03  \
# 0   1595.0   1550.0   1522.0   1505.0   1525.0   1550.0   1590.0   1600.0
# 1   2500.0   2500.0   2500.0   2462.0   2450.0   2400.0   2450.0   2495.0
# 2   2250.0   2250.0   2276.0   2300.0   2295.0   2300.0   2323.0   2365.0
# 3   1600.0   1650.0   1645.0   1695.0   1600.0   1595.0   1695.0   1600.0
# 4   1300.0   1296.0   1312.0   1315.0   1330.0   1363.0   1390.0   1409.0
#
#    2016-04  2016-05  2016-06  2016-07  2016-08  2016-09  2016-10  2016-11  \
# 0   1600.0   1600.0   1599.0   1650.0   1600.0   1588.5   1600.0   1637.0
# 1   2500.0   2500.0   2545.0   2549.0   2500.0   2595.0   2600.0   2595.0
# 2   2350.0   2350.0   2350.0   2330.0   2330.0   2350.0   2300.0   2330.0
# 3   1600.0   1650.0   1650.0   1607.0   1600.0   1578.0   1550.0   1500.0
# 4   1399.0   1395.0   1390.0   1382.0   1368.5   1413.0   1370.0   1346.0
#
#    2016-12  2017-01  2017-02  2017-03  2017-04  2017-05  2017-06  2017-07  \
# 0   1500.0   1549.0   1500.0   1530.0   1575.0   1575.0   1575.0   1575.0
# 1   2400.0   2400.0   2395.0   2400.0   2450.0   2500.0   2500.0   2500.0
# 2   2295.0   2350.0   2450.0   2495.0   2500.0   2500.0   2500.0   2495.0
# 3   1525.0   1550.0   1550.0   1595.0   1600.0   1631.0   1635.0   1605.0
# 4   1295.0   1407.5   1415.0   1470.0   1500.0   1500.0   1540.0   1515.0
#
#    2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0   1559.0   1535.0   1510.0   1500.0   1509.0   1520.0   1550.0   1580.0
# 1   2500.0   2490.0   2400.0   2400.0   2395.0   2375.0   2365.0   2400.0
# 2   2495.0   2495.0   2495.0   2472.0   2475.0   2454.0   2495.0   2499.0
# 3   1600.0   1600.0   1595.0   1595.0   1595.0   1597.0   1620.0   1660.0
# 4   1518.0   1491.5   1450.0   1485.0   1495.0   1490.0   1542.5   1550.0
#
#    2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  \
# 0   1600.0   1620.0   1634.0   1649.0   1642.0   1600.0   1600.0   1600.0
# 1   2450.0   2500.0   2500.0   2500.0   2500.0   2499.0   2415.0   2400.0
# 2   2500.0   2500.0   2520.0   2550.0   2575.0   2544.0   2560.0   2560.0
# 3   1695.0   1700.0   1724.0   1700.0   1699.0   1750.0   1695.0   1698.0
# 4   1560.0   1579.0   1575.0   1595.0   1595.0   1589.0   1609.0   1600.0
#
#    2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 0   1600.0   1600.0   1625.0   1650.0   1668.0   1675.0   1683.0   1683.0
# 1   2400.0   2400.0   2400.0   2450.0   2500.0   2500.0   2550.0   2500.0
# 2   2568.5   2556.0   2585.0   2595.0   2605.0   2620.0   2628.0   2635.0
# 3   1700.0   1745.0   1770.0   1795.0   1765.0   1750.0   1750.0   1750.0
# 4   1600.0   1592.0   1595.0   1611.0   1600.0   1595.0   1585.0   1582.0
#
#    2019-08  2019-09  2019-10  2019-11  2019-12
# 0   1660.0   1632.0   1600.0   1599.0   1595.0
# 1   2545.0   2500.0   2450.0   2400.0   2375.0
# 2   2650.0   2670.0   2650.0   2650.0   2650.0
# 3   1705.0   1700.0   1640.0   1615.0   1600.0
# 4   1575.0   1580.0   1575.0   1572.0   1582.0

# %% [markdown]
# ## 3. Cleaning up columns
#
# It's pretty common that raw data files will have way more columns than you need, with obscure names as well.
#
# My favorite approach is to start by creating _new_ columns with better names. This is more flexible than renaming columns in place because it's easier to undo.

# %%
df['rent'] = df['2019-12']  # we only care about the most recent values
df['region'] = df['RegionName']
df['ranking'] = df['SizeRank']

# %% [markdown]
# What did this do?

# %%
df.head(2)  # passing an integer gives us a custom number of rows
# Out:
#       RegionName  SizeRank  2010-01  2010-02  2010-03  2010-04  2010-05  \
# 0  United States         0      NaN      NaN   1350.0   1350.0   1350.0
# 1   New York, NY         1      NaN      NaN      NaN      NaN      NaN
#
#    2010-06  2010-07  2010-08  2010-09  2010-10  2010-11  2010-12  2011-01  \
# 0   1400.0   1300.0   1250.0   1225.0   1250.0   1250.0   1295.0   1200.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2011-02  2011-03  2011-04  2011-05  2011-06  2011-07  2011-08  2011-09  \
# 0   1250.0   1300.0   1400.0   1400.0   1395.0   1395.0   1400.0   1350.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2011-10  2011-11  2011-12  2012-01  2012-02  2012-03  2012-04  2012-05  \
# 0   1250.0   1200.0   1250.0   1250.0   1250.0   1300.0   1325.0   1375.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2012-06  2012-07  2012-08  2012-09  2012-10  2012-11  2012-12  2013-01  \
# 0   1345.0   1319.0   1325.0   1300.0   1295.0   1300.0   1300.0   1250.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2013-02  2013-03  2013-04  2013-05  2013-06  2013-07  2013-08  2013-09  \
# 0   1300.0   1350.0   1350.0   1370.0   1350.0   1405.0   1425.0   1500.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2013-10  2013-11  2013-12  2014-01  2014-02  2014-03  2014-04  2014-05  \
# 0   1600.0   1500.0   1600.0   1600.0   1595.0   1600.0   1638.0   1715.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2014-06  2014-07  2014-08  2014-09  2014-10  2014-11  2014-12  2015-01  \
# 0   1750.0   1550.0   1550.0   1519.0   1500.0   1495.0   1450.0   1475.0
# 1      NaN      NaN   2545.0   2595.0   2595.0   2550.0   2500.0   2500.0
#
#    2015-02  2015-03  2015-04  2015-05  2015-06  2015-07  2015-08  2015-09  \
# 0   1500.0   1528.0   1540.0   1599.0   1580.0   1595.0   1595.0   1550.0
# 1   2500.0   2500.0   2500.0   2595.0   2545.0   2500.0   2500.0   2500.0
#
#    2015-10  2015-11  2015-12  2016-01  2016-02  2016-03  2016-04  2016-05  \
# 0   1522.0   1505.0   1525.0   1550.0   1590.0   1600.0   1600.0   1600.0
# 1   2500.0   2462.0   2450.0   2400.0   2450.0   2495.0   2500.0   2500.0
#
#    2016-06  2016-07  2016-08  2016-09  2016-10  2016-11  2016-12  2017-01  \
# 0   1599.0   1650.0   1600.0   1588.5   1600.0   1637.0   1500.0   1549.0
# 1   2545.0   2549.0   2500.0   2595.0   2600.0   2595.0   2400.0   2400.0
#
#    2017-02  2017-03  2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  \
# 0   1500.0   1530.0   1575.0   1575.0   1575.0   1575.0   1559.0   1535.0
# 1   2395.0   2400.0   2450.0   2500.0   2500.0   2500.0   2500.0   2490.0
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  2018-05  \
# 0   1510.0   1500.0   1509.0   1520.0   1550.0   1580.0   1600.0   1620.0
# 1   2400.0   2400.0   2395.0   2375.0   2365.0   2400.0   2450.0   2500.0
#
#    2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 0   1634.0   1649.0   1642.0   1600.0   1600.0   1600.0   1600.0   1600.0
# 1   2500.0   2500.0   2500.0   2499.0   2415.0   2400.0   2400.0   2400.0
#
#    2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 0   1625.0   1650.0   1668.0   1675.0   1683.0   1683.0   1660.0   1632.0
# 1   2400.0   2450.0   2500.0   2500.0   2550.0   2500.0   2545.0   2500.0
#
#    2019-10  2019-11  2019-12    rent         region  ranking
# 0   1600.0   1599.0   1595.0  1595.0  United States        0
# 1   2450.0   2400.0   2375.0  2375.0   New York, NY        1

# %% [markdown]
# Then, we can make a copy of the DataFrame with just the columns we want:

# %%
rents = df[['region', 'rent', 'ranking']].copy()

#be careful about using square brackets here. Wont work otherwise. One set surrounds the series/list.

# %% [markdown]
# (For the curious: This will also work without `copy()` at the end. But sometimes you'll run into errors later on. **Without** `copy()`, the new variable only contains a reference to sections of the original DataFrame -- so if you try to change any of the data values, you run into problems. **With** copy, you truly duplicate the contents.)

# %%
rents.head()
# Out:
#                                region    rent  ranking
# 0                       United States  1595.0        0
# 1                        New York, NY  2375.0        1
# 2  Los Angeles-Long Beach-Anaheim, CA  2650.0        2
# 3                         Chicago, IL  1600.0        3
# 4               Dallas-Fort Worth, TX  1582.0        4

# %% [markdown]
# ## 4. Descriptive statistics
#
# Pandas provides a panel of pre-defined descriptive statistics that are a good place to start:

# %%
rents.describe()
# Out:
#               rent     ranking
# count   384.000000  384.000000
# mean   1071.756510  191.500000
# std     450.230033  110.995495
# min     495.000000    0.000000
# 25%     750.000000   95.750000
# 50%     930.000000  191.500000
# 75%    1250.000000  287.250000
# max    3273.500000  383.000000

# %% [markdown]
# Too many decimals! We can fix this with another setting:

# %%
pd.set_option("display.precision", 1)  # number of decimal places

# %%
rents.describe()
# Out:
#          rent  ranking
# count   384.0    384.0
# mean   1071.8    191.5
# std     450.2    111.0
# min     495.0      0.0
# 25%     750.0     95.8
# 50%     930.0    191.5
# 75%    1250.0    287.2
# max    3273.5    383.0

# %% [markdown]
# The "descriptions" of non-numeric columns follows a different format, and we have to ask for them separately:

# %%
rents['region'].describe()
# Out:
# count                384
# unique               384
# top       Hagerstown, WV
# freq                   1
# Name: region, dtype: object

# %% [markdown]
# There are also built-in functions to provide individual stats:

# %%
rents['rent'].max()
# Out:
# 3273.5

# %% [markdown]
# You can use functions that are defined in other places, too:

# %%
max(rents['rent'])
# Out:
# 3273.5

# %%
import numpy as np

np.max(rents['rent'])

# numpy is a numerical library, while pandas is for data analysis, such as labeling columns and cleaning and organizing data
# Out:
# 3273.5

# %% [markdown]
# What's going on with the different kinds of syntax for calling functions?
#
# Functions that you run by appending their name to the DataFrame, like `df['colname'].max()` are part of Pandas. (Technically, these are called "methods" rather than functions, for reasons we don't need to go into.)
#
# Here's the full list: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.html
#
# With functions that come from other places, you pass the data you're evaluating into the function.
#
# Here are some other common sources for math functions:
#
# - Core Python, like `max(list)`: https://docs.python.org/3/library/functions.html
# - Core Python's math library: https://docs.python.org/3/library/math.html
# - NumPy, like `np.max(list)`: https://numpy.readthedocs.io/en/latest/reference/routines.math.html

# %% [markdown]
# ## 5. Digging into the data
#
# Which cities have the highest and lowest rents?

# %%
rents.nlargest(n=10, columns='rent')

#cities with largest rents, only shows top 10 rows
# Out:
#                                  region    rent  ranking
# 11                    San Francisco, CA  3273.5       11
# 34                         San Jose, CA  3172.5       34
# 276                            Napa, CA  2908.0      276
# 119       Santa Maria-Santa Barbara, CA  2780.0      119
# 168                      Santa Cruz, CA  2700.0      168
# 349                        Key West, FL  2700.0      349
# 2    Los Angeles-Long Beach-Anaheim, CA  2650.0        2
# 10                           Boston, MA  2575.0       10
# 1                          New York, NY  2375.0        1
# 17                        San Diego, CA  2350.0       17

# %%
rents.nsmallest(n=10, columns='rent')
# Out:
#                  region   rent  ranking
# 265        Florence, AL  495.0      265
# 357      Charleston, IL  500.0      357
# 248          Albany, GA  525.0      248
# 219     Bloomington, IL  540.0      219
# 260  Jefferson City, MO  550.0      260
# 373           Rolla, MO  550.0      373
# 376       Pittsburg, KS  550.0      376
# 257     Rocky Mount, NC  575.0      257
# 309       Bluefield, WV  577.5      309
# 268       Johnstown, PA  595.0      268

# %% [markdown]
# What if we want to limit it to the 50 largest metros? This requires filtering the data.
#
# `df.loc[expression]` will filter a DataFrame to include only the specified rows and columns. For arcane reasons, the expression needs to refer to columns by their full identifier, not just their label.
#
# Generally, we use square brackets when we're **accessing a subset of data**, or defining a list. We use parentheses everywhere else.

# %%
rents.loc[rents['ranking'] < 50].nlargest(n=5, columns='rent')

#look at ranking and check whether less than 50 -- filter for 50 largest metros -- and report the 5 largest by rent
# Out:
#                                 region    rent  ranking
# 11                   San Francisco, CA  3273.5       11
# 34                        San Jose, CA  3172.5       34
# 2   Los Angeles-Long Beach-Anaheim, CA  2650.0        2
# 10                          Boston, MA  2575.0       10
# 1                         New York, NY  2375.0        1

# %%
rents.loc[rents['ranking'] < 50].nsmallest(n=5, columns='rent')
# Out:
#                region   rent  ranking
# 42  Oklahoma City, OK  850.0       42
# 29      Cleveland, OH  925.0       29
# 41        Memphis, TN  940.0       41
# 33   Indianapolis, IN  944.0       33
# 49     Birmingham, AL  974.0       49

# %% [markdown]
# Which are the large metros with rents over $1,800?

# %%
rents.loc[(rents['ranking'] < 50) & (rents['rent'] > 1800)]
# Out:
#                                 region    rent  ranking
# 1                         New York, NY  2375.0        1
# 2   Los Angeles-Long Beach-Anaheim, CA  2650.0        2
# 7                       Washington, DC  2085.0        7
# 8            Miami-Fort Lauderdale, FL  1912.0        8
# 10                          Boston, MA  2575.0       10
# 11                   San Francisco, CA  3273.5       11
# 15                         Seattle, WA  1875.0       15
# 17                       San Diego, CA  2350.0       17
# 34                        San Jose, CA  3172.5       34

# %% [markdown]
# You need the extra parentheses so Python knows to evaluate each expression separately before calculating the union. (Otherwise there's a syntax error.) The symbol for "or" is `|`, from under the delete key.
#
# If your expressions get complicated, you can break the lines between sets of parentheses:

# %%
rents.loc[(rents['region'].str.contains('CA')) & 
          (rents['rent'] > 2000)]
# Out:
#                                  region    rent  ranking
# 2    Los Angeles-Long Beach-Anaheim, CA  2650.0        2
# 11                    San Francisco, CA  3273.5       11
# 17                        San Diego, CA  2350.0       17
# 34                         San Jose, CA  3172.5       34
# 66                          Ventura, CA  2309.0       66
# 105                      Santa Rosa, CA  2240.0      105
# 119       Santa Maria-Santa Barbara, CA  2780.0      119
# 121                         Salinas, CA  2195.0      121
# 168                      Santa Cruz, CA  2700.0      168
# 276                            Napa, CA  2908.0      276

# %% [markdown]
# ## 6. Saving data tables to disk
#
# Often you'll want to save the results of your analysis to disk, either for record keeping or so you can look at the data using other tools. This is easy:

# %%
rents.to_csv('processed_rents.csv')

# %% [markdown]
# Now you should see it in the JupyterHub file browser.

# %% [markdown]
# ## Exercises
#
# Are there any cities in California, Oregon, or Washington where the mean rent is below $1500?

# %%
rents.loc[((rents['region'].str.contains('CA')) | 
           (rents['region'].str.contains('OR')) | 
           (rents['region'].str.contains('WA'))) &
          (rents['rent'] < 1500)]
# Out:
#                region    rent  ranking
# 56         Fresno, CA  1010.0       56
# 63    Bakersfield, CA   895.0       63
# 99        Spokane, WA  1085.0       99
# 102       Modesto, CA  1300.0      102
# 110       Visalia, CA   975.0      110
# 130         Salem, OR  1305.0      130
# 143        Eugene, OR  1495.0      143
# 171        Merced, CA  1090.0      171
# 173     Kennewick, WA  1110.5      173
# 176       Olympia, WA  1470.0      176
# 183        Yakima, WA   895.0      183
# 193         Chico, CA  1095.0      193
# 206       Medford, OR  1325.0      206
# 208    Bellingham, WA  1400.0      208
# 226       Redding, CA   924.0      226
# 235     Yuba City, CA   982.0      235
# 278        Eureka, CA  1000.0      278
# 301  Mount Vernon, WA  1395.0      301
# 302        Albany, OR  1095.0      302
# 312      Longview, WA   925.0      312
# 336     Corvallis, OR  1250.0      336
# 344    Oak Harbor, WA  1250.0      344
# 359     Clearlake, CA  1200.0      359
# 362   Walla Walla, WA   997.5      362

# %% [markdown]
# Can you plot a histogram of nationwide rents, using `.plot.hist()`?
#
# You'll need to run this on a single Series, rather than on a DataFrame as in the `.plot.scatter()` example.
#
# `.plot.hist()` does not require any arguments.

# %%
rents.plot.hist('rent')

# %% [markdown]
# Can you make the histogram smoother?
#
# `.plot.hist()` takes an optional argument named `bins`, which defines how many buckets the data is divided into.

# %%
rents.plot.hist('rent', bins=50)

# %% [markdown]
# (You might want to create a new notebook for the next part, to keep things cleaner.)
#
# Make a new variable showing the percentage change in rents from 2014 to 2019.
#
# You can do this analogously to how we renamed the variables, but including a math expression on the right-hand side of the `=` assignment operator.
#
# What's the mean and range of the changes?
#
# Which cities had the largest and smallest changes?
#
# What does a histogram of the changes look like?

# %%
df['pchange'] = (df['2019-12'] - df['2014-12']) / df['2014-12']
df['place'] = df['region']
rentchange = df[['place','pchange']].copy()
rentchange.head()
# Out:
#                                 place  pchange
# 0                       United States  1.0e-01
# 1                        New York, NY -5.0e-02
# 2  Los Angeles-Long Beach-Anaheim, CA  2.3e-01
# 3                         Chicago, IL  7.0e-02
# 4               Dallas-Fort Worth, TX  2.5e-01

# %%
rentchange.describe()
# Out:
#        pchange
# count    184.0
# mean       0.3
# std        0.2
# min       -0.1
# 25%        0.1
# 50%        0.2
# 75%        0.4
# max        0.9

# %%
rentchange.loc[(rentchange['pchange'] > .7)]
# Out:
#             place  pchange
# 77   Stockton, CA      0.9
# 116      Reno, NV      0.9
# 130     Salem, OR      0.9
# 143    Eugene, OR      0.8

# %%
rentchange.loc[(rentchange['pchange']) < -.05]
# Out:
#                      place  pchange
# 111         Shreveport, LA -6.0e-02
# 131          Anchorage, AK -7.7e-02
# 163             Duluth, MN -5.8e-02
# 201         Las Cruces, NM -6.8e-02
# 327          Manhattan, KS -8.5e-02
# 364  Fort Leonard Wood, MO -1.0e-01

# %%
changes = pd.Series(rentchange['pchange'])
changes.plot.hist()

# %%
rentchange['pchange'].max()
# Out:
# 0.9381818181818182

# %%
rentchange['pchange'].min()
# Out:
# -0.1032258064516129
